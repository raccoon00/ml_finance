# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import asyncio

# %%
import finance.moex.shares as mf

vtb = mf.share_adjusted("VTBR", verbose=True)
trnf = mf.share_adjusted("TRNFP")
sber = mf.share_adjusted("SBER")
gazp = mf.share_adjusted("GAZP")
pik = mf.share_adjusted("PIKK")

vtb, trnf, sber, gazp, pik = await asyncio.gather(vtb, trnf, sber, gazp, pik)

print(trnf.columns)
# Out:
#             <div style="border-left:6px solid #8957e5; padding:12px 14px; margin:10px 0; background:#0d1117; color:#c9d1d9; border-radius:8px;">
#                 <div style="font-weight:700; font-size:14px; color:#8957e5; margin-bottom:6px;">📌 MOEX VTBR</div>
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Бумага</span>
#                     <span style="font-weight:600; color:#8957e5;">VTBR</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Время fetch</span>
#                     <span style="font-weight:600; color:#39c5cf;">422 мс</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">История</span>
#                     <span style="font-weight:600; color:#1f6feb;">2013-02-28 → 2025-10-21</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Торговых дней</span>
#                     <span style="font-weight:600; color:#1f6feb;">3224</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Дивиденды (шт.)</span>
#                     <span style="font-weight:600; color:#2ea043;">11</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Средний интервал</span>
#                     <span style="font-weight:600; color:#2ea043;">402.8 дн.</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Первая выплата</span>
#                     <span style="font-weight:600; color:#2ea043;">2014-07-01</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Последняя выплата</span>
#                     <span style="font-weight:600; color:#2ea043;">2025-07-11</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Сплиты</span>
#                     <span style="font-weight:600; color:#d29922;">0</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Объединения</span>
#                     <span style="font-weight:600; color:#d29922;">1</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Совокупный коэффициент</span>
#                     <span style="font-weight:600; color:#d29922;">0.0002</span>
#                 </div>
#
#             </div>
# Index(['open', 'high', 'low', 'close', 'volume', 'dividend', 'split_ratio',
#        'adj_close', 'logret'],
#       dtype='object')

# %%
import finance.moex.index_groups as idx_groups

igs = idx_groups.get_df()
display(igs)
# Out:
#          index                                               desc  \
# 0        IMOEX                            Индекс МосБиржи (рубли)
# 1      IMOEX10                                 Индекс МосБиржи 10
# 2         RTSI                            RTS Index (доллары США)
# 3       IMOEX2              Индекс МосБиржи 2 (расширенный рынок)
# 4       MOEXOG                                        Нефть и газ
# 5       MOEXFN                                  Финансовый сектор
# 6       MOEXCN                             Потребительский сектор
# 7       MOEXMM                                   Металлы и добыча
# 8       MOEXCH                                 Химия и нефтехимия
# 9       MOEXTN                                   Телекоммуникации
# 10      MOEXTR                                          Транспорт
# 11      MOEXEU                                         Энергетика
# 12      MOEXIN                                     Промышленность
# 13      MOEXRE                                       Недвижимость
# 14     RUGBITR  Индекс государственных облигаций RGBI Total Re...
# 15      RUGBCP             Корпоративные облигации — общий индекс
# 16      RUGBTR   Индекс корпоративных облигаций полной доходности
# 17      RUGBMB                     Индекс муниципальных облигаций
# 18      USDCBX                          USD/RUB индикативный курс
# 19      EURCBX                          EUR/RUB индикативный курс
# 20      CNYCBX                          CNY/RUB индикативный курс
# 21  USDRUB_TOM                               USD/RUB завтра (T+1)
# 22    IMOEXESG                                Индекс МосБиржи ESG
# 23     IMOEXBC               Индекс МосБиржи устойчивого развития
# 24     MOEXINN                      Индекс инновационных компаний
# 25     MOEXIBB                           Индекс интернет-компаний
#
#                         group
# 0                broad_market
# 1                broad_market
# 2                broad_market
# 3                broad_market
# 4                    sectoral
# 5                    sectoral
# 6                    sectoral
# 7                    sectoral
# 8                    sectoral
# 9                    sectoral
# 10                   sectoral
# 11                   sectoral
# 12                   sectoral
# 13                   sectoral
# 14                      bonds
# 15                      bonds
# 16                      bonds
# 17                      bonds
# 18                   currency
# 19                   currency
# 20                   currency
# 21                   currency
# 22  custom_groups/sustainable
# 23  custom_groups/sustainable
# 24   custom_groups/innovation
# 25   custom_groups/innovation

# %%
import finance.moex.index as index

ofz = index.fetch_index(verbose=True)
og = index.fetch_index("MOEXOG", verbose=True)
ofz, og = await asyncio.gather(ofz, og)
# Out:
#             <div style="border-left:6px solid #8957e5; padding:12px 14px; margin:10px 0; background:#0d1117; color:#c9d1d9; border-radius:8px;">
#                 <div style="font-weight:700; font-size:14px; color:#8957e5; margin-bottom:6px;">📌 MOEX RGBITR</div>
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Индекс</span>
#                     <span style="font-weight:600; color:#8957e5;">RGBITR</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Время fetch</span>
#                     <span style="font-weight:600; color:#39c5cf;">3583 мс</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">История</span>
#                     <span style="font-weight:600; color:#1f6feb;">2012-03-05 → 2025-10-21</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Торговых дней</span>
#                     <span style="font-weight:600; color:#1f6feb;">3428</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Первое значение</span>
#                     <span style="font-weight:600; color:#2ea043;">282.09</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Последнее значение</span>
#                     <span style="font-weight:600; color:#2ea043;">709.48</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Совокупная доходность</span>
#                     <span style="font-weight:600; color:#d29922;">151.51%</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Годовая доходность (CAGR)</span>
#                     <span style="font-weight:600; color:#d29922;">7.02%</span>
#                 </div>
#
#             </div>
#             <div style="border-left:6px solid #8957e5; padding:12px 14px; margin:10px 0; background:#0d1117; color:#c9d1d9; border-radius:8px;">
#                 <div style="font-weight:700; font-size:14px; color:#8957e5; margin-bottom:6px;">📌 MOEX MOEXOG</div>
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Индекс</span>
#                     <span style="font-weight:600; color:#8957e5;">MOEXOG</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Время fetch</span>
#                     <span style="font-weight:600; color:#39c5cf;">6109 мс</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">История</span>
#                     <span style="font-weight:600; color:#1f6feb;">2004-12-30 → 2025-10-21</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Торговых дней</span>
#                     <span style="font-weight:600; color:#1f6feb;">5206</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Первое значение</span>
#                     <span style="font-weight:600; color:#2ea043;">1000.00</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Последнее значение</span>
#                     <span style="font-weight:600; color:#2ea043;">6985.12</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Совокупная доходность</span>
#                     <span style="font-weight:600; color:#d29922;">598.51%</span>
#                 </div>
#
#
#                 <div style="display:flex; justify-content:space-between; padding:4px 0; border-bottom:1px solid rgba(240,246,252,0.06);">
#                     <span style="color:#8b949e;">Годовая доходность (CAGR)</span>
#                     <span style="font-weight:600; color:#d29922;">9.87%</span>
#                 </div>
#
#             </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_style("darkgrid")

# %%
def plot_share(data, name=""):
    sns.lineplot(data=data, x=data.index, y="adj_close", label="TRNFP ADJ", alpha=0.5)
    sns.lineplot(data=data, x=data.index, y="close", label="TRNFP", alpha=0.5)

    div_data = data[data["dividend"] != 0]
    div_sizes = div_data["dividend"] / div_data["close"] * 500
    ax = sns.scatterplot(data=div_data, x=div_data.index, y="close", c="r", size=div_sizes, legend=False)
    
    plt.tight_layout()
    if name:
        plt.title(name)
    plt.show()

# %%
plot_share(trnf, "ТрансНефть")
plot_share(vtb, "ВТБ")
plot_share(sber, "Сбер")
plot_share(gazp, "Газпром")
plot_share(pik, "Пик")

# %%
b = 20
i = 0
org = sber

idx = (org["dividend"] != 0.0).to_numpy().flatten().nonzero()[0][i].item()
iota = list(range(idx - b, idx + b))
org_subs = org.iloc[iota].copy()
plot_share(org_subs)
